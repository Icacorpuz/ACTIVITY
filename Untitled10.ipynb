# %% [markdown]
# <a href="https://colab.research.google.com/github/Icacorpuz/ACTIVITY/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_bike = pd.read_csv('https://raw.githubusercontent.com/Icacorpuz/ACTIVITY/main/RailsToTrails_National%20Count%20Data_week.csv')

# %%
df_bike.head()
# Out:
#   Timeframe     Week of   2019 counts (14 counters)  \
# 0    Week 1  12/30/2020                     68957.0
# 1    Week 2    1/6/2020                     34778.0
# 2    Week 3   1/13/2020                     32065.0
# 3    Week 4   1/20/2020                     35016.0
# 4    Week 5   1/27/2020                     33627.0
#
#     2020 counts (14 counters) Change 2019-2020
# 0                     93654.0              36%
# 1                     46964.0              35%
# 2                     38302.0              19%
# 3                     41506.0              19%
# 4                     46335.0              38%

# %%
df_data = (df_bike [df_bike['Week of'] >= '31-July'])
df_data.head()
# Out:
#    Timeframe    Week of   2019 counts (14 counters)  \
# 14   Week 15   4/6/2020                     83893.0
# 15   Week 16  4/13/2020                     71677.0
# 16   Week 17  4/20/2020                     87834.0
# 17   Week 18  4/27/2020                     88284.0
# 18   Week 19   5/4/2020                     94980.0
#
#      2020 counts (14 counters) Change 2019-2020
# 14                    107420.0              28%
# 15                    122291.0              71%
# 16                    106246.0              21%
# 17                    109459.0              24%
# 18                    109391.0              15%

# %%
df_fil = df_bike['Week of'] >='31-July'
df_fil.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Week of, dtype: bool

# %%
df_bike.loc[df_fil].head()
# Out:
#    Timeframe    Week of   2019 counts (14 counters)  \
# 14   Week 15   4/6/2020                     83893.0
# 15   Week 16  4/13/2020                     71677.0
# 16   Week 17  4/20/2020                     87834.0
# 17   Week 18  4/27/2020                     88284.0
# 18   Week 19   5/4/2020                     94980.0
#
#      2020 counts (14 counters) Change 2019-2020
# 14                    107420.0              28%
# 15                    122291.0              71%
# 16                    106246.0              21%
# 17                    109459.0              24%
# 18                    109391.0              15%

# %%
df_bike.loc[df_fil, :].head()
# Out:
#    Timeframe    Week of   2019 counts (14 counters)  \
# 14   Week 15   4/6/2020                     83893.0
# 15   Week 16  4/13/2020                     71677.0
# 16   Week 17  4/20/2020                     87834.0
# 17   Week 18  4/27/2020                     88284.0
# 18   Week 19   5/4/2020                     94980.0
#
#      2020 counts (14 counters) Change 2019-2020
# 14                    107420.0              28%
# 15                    122291.0              71%
# 16                    106246.0              21%
# 17                    109459.0              24%
# 18                    109391.0              15%
